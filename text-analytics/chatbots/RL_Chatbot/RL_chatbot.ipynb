# %% [markdown]
# # Reinforcement learning for chatbot

# %% [markdown]
# Credit : Jiwei Li and  Lisen Dai

# %% [markdown]
# ## Intro :
# Recent neural models of dialogue generation
# offer great promise for generating responses
# for conversational agents, but tend to be shortsighted, predicting utterances one at a time
# while ignoring their influence on future outcomes. Modeling the future direction of a dialogue is crucial to generating coherent, interesting dialogues, a need which led traditional NLP models of dialogue to draw on reinforcement learning. <etl. Jiwei Li>
#
# paper link : https://arxiv.org/pdf/1606.01541.pdf

# %% [markdown]
# In this work they simulate conversations between the two virtual agents and have them take turns talking with each
# other. <etl. Jiwei Li>

# %% [markdown]
# ![img1.png](data:image/png;base64,...)

# %% [markdown]
# The simulation proceeds as follows: at the
# initial step, a message from the training set is fed to
# the first agent. The agent encodes the input message
# to a vector representation and starts decoding to generate a response output. Combining the immediate
# output from the first agent with the dialogue history,
# the second agent updates the state by encoding the
# dialogue history into a representation and uses the
# decoder RNN to generate responses, which are subsequently fed back to the first agent, and the process
# is repeated.

# %% [markdown]
# #### Installing the Dependencies

# %%
# !pip install torch==1.6
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 748.8 MB 13 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.6.0 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.6.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.6.0 which is incompatible.
# fastai 2.7.9 requires torch<1.14,>=1.7, but you have torch 1.6.0 which is incompatible.
# ...

# %% [markdown]
# ##### Unzip the file

# %% [markdown]
# **Upload the RL_chatbot.zip file from repo to session storage**

# %%
# !unzip '/content/RL_Chatbot.zip'
# Out:
# Archive:  /content/RL_Chatbot.zip
#    creating: RL_Chatbot/
#   inflating: RL_Chatbot/4800_checkpoint.tar
#   inflating: RL_Chatbot/5000_checkpoint.tar
#    creating: RL_Chatbot/data/
#   inflating: RL_Chatbot/data/.DS_Store
#   inflating: RL_Chatbot/data/dialogues_act.txt
#   inflating: RL_Chatbot/data/dialogues_emotion.txt
#   inflating: RL_Chatbot/data/dialogues_text.txt
#   inflating: RL_Chatbot/data/dialogues_topic.txt
#   inflating: RL_Chatbot/data/readme.txt
#    creating: RL_Chatbot/data/test/
#   inflating: RL_Chatbot/data/test/dialogues_act_test.txt
#   inflating: RL_Chatbot/data/test/dialogues_emotion_test.txt
#   inflating: RL_Chatbot/data/test/dialogues_test.txt
#   inflating: RL_Chatbot/data/test/formatted_dialogues_test.txt
#   inflating: RL_Chatbot/data/test.zip
#    creating: RL_Chatbot/data/train/
#   inflating: RL_Chatbot/data/train/dialogues_act_train.txt
#   inflating: RL_Chatbot/data/train/dialogues_emotion_train.txt
# ...

# %% [markdown]
# Chatbot Interface

# %% [markdown]
# Using the pretrained checkpoints with 5000 iteration for the demonstration

# %%
# !python '/content/RL_Chatbot/naive_run.py'
# Out:
# Start preparing training data ...
# Reading lines...
# Read 76053 sentence pairs
# Trimmed to 37041 sentence pairs
# Counting words...
# Counted words: 9514
#
# pairs:
# ['say jim how about going for a few beers after dinner ?', 'you know that is tempting but is really not good for our fitness .']
# ['you know that is tempting but is really not good for our fitness .', 'what do you mean ? it will help us to relax .']
# ['good .let s go now .', 'all right .']
# ['really ? i think that s impossible !', 'you mean push ups ?']
# ['you mean push ups ?', 'yeah !']
# ['can you study with the radio on ?', 'no i listen to background music .']
# ['no i listen to background music .', 'what is the difference ?']
# ['what is the difference ?', 'the radio has too many comerials .']
# ['the radio has too many comerials .', 'that s true but then you have to buy a record player .']
# ['don t worry .he is an acrobat', 'i see .']
# keep_words 5659 / 9511 = 0.5950
# ...

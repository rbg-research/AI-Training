# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rbg-research/AI-Training/blob/main/voice-analytics/voice-analytics-deep-learning/session-1/Tutorial-4.ipynb)

# %% [markdown]
# # Audio Classification - Common Voice Corpus - Gender Prediction

# %%
# !pip3 install datasets

# %%
# !pip3 install librosa

# %%
# !pip3 install matplotlib

# %%
# !pip3 install pandas

# %%
# !pip3 install sklearn

# %%
# !pip3 install tensorflow

# %%
import random
random.seed(7)

# %% [markdown]
# ### 1. Data Preparation

# %%
import datasets
import pandas as pd

# %%
# loading train and test data 

dataset = datasets.load_dataset('common_voice', 'ta') # loads tamil corpus

train = dataset["train"] # get the train split

test = dataset["test"] # get the test split
# Out:
# Reusing dataset common_voice (/home/ubuntu/.cache/huggingface/datasets/common_voice/ta/6.1.0/078d412587e9efeb0ae2e574da99c31e18844c496008d53dc5c60f4159ed639b)
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# making a dataframe for faster processing
train_files, train_labels = dataset["train"]["path"], dataset["train"]["gender"]
train_df = pd.DataFrame.from_dict({"path": train_files, "label": train_labels})

# filtering the sample that doesn't have the gender class
train_df = train_df[train_df["label"]!=""]
train_df = train_df[train_df["label"]!="others"]
# getting audio files and ground truth labels
train_files, train_labels = list(train_df["path"]), list(train_df["label"])



# repeating same steps to test corpus also
test_files, test_labels = dataset["test"]["path"], dataset["test"]["gender"]
test_df = pd.DataFrame.from_dict({"path": test_files, "label": test_labels})

# filtering the sample that doesn't have the gender class
test_df = test_df[test_df["label"]!=""]
test_df = test_df[test_df["label"]!="other"]
# getting audio files and ground truth labels
test_files, test_labels = list(test_df["path"]), list(test_df["label"])

# %%
# number of training samples availble for each class
print("number of train samples per class 'male':", train_labels.count("male"))
print("number of train samples per class 'female':", train_labels.count("female"))
# Out:
# number of train samples per class 'male': 885
# number of train samples per class 'female': 770

# %%
# number of test samples availble for each class
print("number of test samples per class 'male':", test_labels.count("male"))
print("number of test samples per class 'female':", test_labels.count("female"))
# Out:
# number of test samples per class 'male': 1073
# number of test samples per class 'female': 166

# %% [markdown]
# ### 2. Feature Extraction

# %%
import librosa
import numpy as np

# %%
def feature_chromagram(waveform, sample_rate):
    # STFT computed here explicitly; mel spectrogram and MFCC functions do this under the hood
    stft_spectrogram=np.abs(librosa.stft(waveform))
    # Produce the chromagram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    chromagram=np.mean(librosa.feature.chroma_stft(S=stft_spectrogram, sr=sample_rate).T,axis=0)
    return chromagram

def feature_melspectrogram(waveform, sample_rate):
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram=np.mean(librosa.feature.melspectrogram(y=waveform, sr=sample_rate, n_mels=128, fmax=8000).T,axis=0)
    return melspectrogram

def feature_mfcc(waveform, sample_rate):
    # Compute the MFCCs for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # 40 filterbanks = 40 coefficients
    mfc_coefficients=np.mean(librosa.feature.mfcc(y=waveform, sr=sample_rate, n_mfcc=40).T, axis=0) 
    return mfc_coefficients

# %%
def get_features(file):
    # load an individual soundfile
     
    waveform , sr = librosa.load(file, sr=16000)
    sample_rate = sr
    # compute features of soundfile
    chromagram = feature_chromagram(waveform, sample_rate)
    melspectrogram = feature_melspectrogram(waveform, sample_rate)
    mfc_coefficients = feature_mfcc(waveform, sample_rate)

    feature_matrix=np.array([])
    # use np.hstack to stack our feature arrays horizontally to create a feature matrix
    feature_matrix = np.hstack((chromagram, melspectrogram, mfc_coefficients))

    return feature_matrix

# %%
def get_feature_matrix(files, labels):
    temp_feats = list()
    temp_labels = list()
    for file, label in zip(files, labels):
        features = get_features(file)
        temp_feats.append(features)
        temp_labels.append(label)
    return np.array(temp_feats), np.array(temp_labels)

# %%
train_features, train_labels = get_feature_matrix(train_files, train_labels)
test_features, test_labels = get_feature_matrix(test_files, test_labels)
# Out:
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/ubuntu/environments/insights/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
train_features.shape
# Out:
# (1655, 180)

# %%
test_features.shape
# Out:
# (1239, 180)

# %% [markdown]
# ### 3. Train, Validation and Test

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
encoder.fit((train_labels.tolist() + test_labels.tolist()))

encoded_train_labels = encoder.transform(train_labels)
encoded_test_labels = encoder.transform(test_labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    train_features, 
    encoded_train_labels, 
    test_size=0.2, 
    random_state=69
)

# %%
test_features = test_features
encoded_test_labels = encoded_test_labels

# %% [markdown]
# ### 4. Neural Network Classifier

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ##### Base Line Network

# %%
# baseline model
def create_baseline():
    # create model
    model = Sequential()
    model.add(Dense(60, input_dim=train_features.shape[1], activation='relu')) # one hidden layer
    model.add(Dense(1, activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model = create_baseline()
# Out:
# 2021-10-25 01:53:17.021225: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-10-25 01:53:17.079107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 01:53:17.079676: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-10-25 01:53:17.079920: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-25 01:53:17.081841: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-10-25 01:53:17.083010: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-10-25 01:53:17.083263: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-10-25 01:53:17.086202: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-10-25 01:53:17.087310: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-10-25 01:53:17.091314: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-10-25 01:53:17.091428: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 01:53:17.092033: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 01:53:17.092574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-10-25 01:53:17.092990: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-10-25 01:53:17.098795: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2500000000 Hz
# 2021-10-25 01:53:17.099178: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fadac000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-10-25 01:53:17.099193: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-10-25 01:53:17.190334: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 01:53:17.190977: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x8329b30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-10-25 01:53:17.191002: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2021-10-25 01:53:17.191260: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 01:53:17.191813: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-10-25 01:53:17.191873: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-25 01:53:17.191889: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-10-25 01:53:17.191903: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-10-25 01:53:17.191918: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-10-25 01:53:17.191932: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-10-25 01:53:17.191945: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-10-25 01:53:17.191959: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-10-25 01:53:17.192034: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 01:53:17.192628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 01:53:17.193142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-10-25 01:53:17.193192: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-25 01:53:17.194729: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-10-25 01:53:17.194743: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2021-10-25 01:53:17.194751: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2021-10-25 01:53:17.194865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 01:53:17.195423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 01:53:17.195944: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14107 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 60)                10860
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 61
# =================================================================
# Total params: 10,921
# Trainable params: 10,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size=4, epochs=100, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 2021-10-25 01:53:18.237553: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 331/331 [==============================] - 1s 2ms/step - loss: 0.4027 - accuracy: 0.9366 - val_loss: 0.0530 - val_accuracy: 0.9849
# Epoch 2/100
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0304 - accuracy: 0.9924 - val_loss: 0.0804 - val_accuracy: 0.9789
# Epoch 3/100
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.0182 - val_accuracy: 0.9940
# Epoch 4/100
# 331/331 [==============================] - 0s 1ms/step - loss: 5.4583e-04 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9940
# Epoch 5/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.9969e-04 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 0.9940
# Epoch 6/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.2410e-05 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 0.9940
# Epoch 7/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.0886e-05 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9940
# Epoch 8/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.9153e-05 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9940
# Epoch 9/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.6463e-05 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9940
# Epoch 10/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.4291e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9940
# Epoch 11/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.3484e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9940
# Epoch 12/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.1944e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9940
# Epoch 13/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.0434e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9940
# Epoch 14/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.0033e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9940
# Epoch 15/100
# 331/331 [==============================] - 0s 1ms/step - loss: 9.0746e-06 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9940
# Epoch 16/100
# 331/331 [==============================] - 0s 1ms/step - loss: 7.2423e-06 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9940
# Epoch 17/100
# 331/331 [==============================] - 0s 1ms/step - loss: 7.2065e-06 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9940
# Epoch 18/100
# 331/331 [==============================] - 0s 1ms/step - loss: 5.7188e-06 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 0.9940
# Epoch 19/100
# 331/331 [==============================] - 0s 1ms/step - loss: 5.1037e-06 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9970
# Epoch 20/100
# 331/331 [==============================] - 0s 1ms/step - loss: 4.3379e-06 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9940
# Epoch 21/100
# 331/331 [==============================] - 0s 1ms/step - loss: 4.9294e-06 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 0.9940
# Epoch 22/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.7799e-06 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 23/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.7700e-06 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9940
# Epoch 24/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.0220e-06 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 25/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.9130e-06 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 0.9940
# Epoch 26/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.6199e-06 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 27/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.3614e-06 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 0.9970
# Epoch 28/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.1463e-06 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9970
# Epoch 29/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.8606e-06 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9940
# Epoch 30/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.6146e-06 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 31/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.5402e-06 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 32/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.2408e-06 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 33/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.2271e-06 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 34/100
# 331/331 [==============================] - 0s 1ms/step - loss: 9.8122e-07 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 35/100
# 331/331 [==============================] - 0s 1ms/step - loss: 8.4540e-07 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9970
# Epoch 36/100
# 331/331 [==============================] - 0s 1ms/step - loss: 8.4500e-07 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 0.9970
# Epoch 37/100
# 331/331 [==============================] - 0s 1ms/step - loss: 7.1493e-07 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 38/100
# 331/331 [==============================] - 0s 1ms/step - loss: 6.5901e-07 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9970
# Epoch 39/100
# 331/331 [==============================] - 0s 1ms/step - loss: 5.4783e-07 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 40/100
# 331/331 [==============================] - 0s 1ms/step - loss: 4.2833e-07 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 41/100
# 331/331 [==============================] - 0s 1ms/step - loss: 4.0139e-07 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 0.9970
# Epoch 42/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.8164e-07 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 43/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.5339e-07 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 44/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.0294e-07 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 45/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.2848e-07 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 46/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.8662e-07 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 47/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.6302e-07 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 48/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.6340e-07 - accuracy: 1.0000 - val_loss: 5.1568e-04 - val_accuracy: 1.0000
# Epoch 49/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.0231e-07 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 50/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.1455e-07 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 51/100
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1196 - accuracy: 0.9909 - val_loss: 0.1940 - val_accuracy: 0.9940
# Epoch 52/100
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1318 - accuracy: 0.9909 - val_loss: 0.0705 - val_accuracy: 0.9879
# Epoch 53/100
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 0.9977 - val_loss: 0.0736 - val_accuracy: 0.9940
# Epoch 54/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.1185e-06 - accuracy: 1.0000 - val_loss: 0.0724 - val_accuracy: 0.9940
# Epoch 55/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.5761e-06 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9940
# Epoch 56/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.2196e-06 - accuracy: 1.0000 - val_loss: 0.0705 - val_accuracy: 0.9940
# Epoch 57/100
# 331/331 [==============================] - 0s 1ms/step - loss: 9.6075e-07 - accuracy: 1.0000 - val_loss: 0.0695 - val_accuracy: 0.9940
# Epoch 58/100
# 331/331 [==============================] - 0s 1ms/step - loss: 7.6810e-07 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 0.9940
# Epoch 59/100
# 331/331 [==============================] - 0s 1ms/step - loss: 6.3040e-07 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9940
# Epoch 60/100
# 331/331 [==============================] - 0s 1ms/step - loss: 5.1654e-07 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9940
# Epoch 61/100
# 331/331 [==============================] - 0s 1ms/step - loss: 4.2605e-07 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9940
# Epoch 62/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.5426e-07 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9940
# Epoch 63/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.9497e-07 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9940
# Epoch 64/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.4701e-07 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9940
# Epoch 65/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.0954e-07 - accuracy: 1.0000 - val_loss: 0.0635 - val_accuracy: 0.9940
# Epoch 66/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.7708e-07 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9940
# Epoch 67/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.4938e-07 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9940
# Epoch 68/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.2581e-07 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9940
# Epoch 69/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.0594e-07 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 0.9940
# Epoch 70/100
# 331/331 [==============================] - 0s 1ms/step - loss: 9.2037e-08 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9940
# Epoch 71/100
# 331/331 [==============================] - 0s 1ms/step - loss: 7.6352e-08 - accuracy: 1.0000 - val_loss: 0.0591 - val_accuracy: 0.9940
# Epoch 72/100
# 331/331 [==============================] - 0s 1ms/step - loss: 6.5348e-08 - accuracy: 1.0000 - val_loss: 0.0584 - val_accuracy: 0.9940
# Epoch 73/100
# 331/331 [==============================] - 0s 1ms/step - loss: 5.5522e-08 - accuracy: 1.0000 - val_loss: 0.0576 - val_accuracy: 0.9940
# Epoch 74/100
# 331/331 [==============================] - 0s 1ms/step - loss: 4.7160e-08 - accuracy: 1.0000 - val_loss: 0.0569 - val_accuracy: 0.9940
# Epoch 75/100
# 331/331 [==============================] - 0s 1ms/step - loss: 4.0355e-08 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 0.9940
# Epoch 76/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.4344e-08 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9940
# Epoch 77/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.0032e-08 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 0.9940
# Epoch 78/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.5264e-08 - accuracy: 1.0000 - val_loss: 0.0540 - val_accuracy: 0.9940
# Epoch 79/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.1461e-08 - accuracy: 1.0000 - val_loss: 0.0533 - val_accuracy: 0.9940
# Epoch 80/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.8240e-08 - accuracy: 1.0000 - val_loss: 0.0525 - val_accuracy: 0.9940
# Epoch 81/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.5521e-08 - accuracy: 1.0000 - val_loss: 0.0518 - val_accuracy: 0.9940
# Epoch 82/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.3297e-08 - accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 0.9940
# Epoch 83/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.1393e-08 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 0.9940
# Epoch 84/100
# 331/331 [==============================] - 0s 1ms/step - loss: 9.9511e-09 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9940
# Epoch 85/100
# 331/331 [==============================] - 0s 1ms/step - loss: 8.4423e-09 - accuracy: 1.0000 - val_loss: 0.0488 - val_accuracy: 0.9940
# Epoch 86/100
# 331/331 [==============================] - 0s 1ms/step - loss: 7.4490e-09 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 0.9940
# Epoch 87/100
# 331/331 [==============================] - 0s 1ms/step - loss: 6.3126e-09 - accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 0.9940
# Epoch 88/100
# 331/331 [==============================] - 0s 1ms/step - loss: 5.5224e-09 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9940
# Epoch 89/100
# 331/331 [==============================] - 0s 1ms/step - loss: 4.8633e-09 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 0.9940
# Epoch 90/100
# 331/331 [==============================] - 0s 1ms/step - loss: 4.3182e-09 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9940
# Epoch 91/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.8119e-09 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9940
# Epoch 92/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.4585e-09 - accuracy: 1.0000 - val_loss: 0.0439 - val_accuracy: 0.9940
# Epoch 93/100
# 331/331 [==============================] - 0s 1ms/step - loss: 3.1442e-09 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9940
# Epoch 94/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.8626e-09 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9940
# Epoch 95/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.6202e-09 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9940
# Epoch 96/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.3931e-09 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9940
# Epoch 97/100
# 331/331 [==============================] - 0s 1ms/step - loss: 2.1891e-09 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9940
# Epoch 98/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.9962e-09 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9940
# Epoch 99/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.8064e-09 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9940
# Epoch 100/100
# 331/331 [==============================] - 0s 1ms/step - loss: 1.6358e-09 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9940

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

y_pred = model.predict_classes(test_features)
y_true = encoded_test_labels
print(f'Test Set Accuracy score =  {100*accuracy_score(y_true, y_pred):.3f}%') #same as model.score(X_test, y_test)
print(f'Test Set Precision score =  {100*precision_score(y_true, y_pred, average="macro"):.3f}%')
print(f'Test Set Recall score =  {100*recall_score(y_true, y_pred, average="macro"):.3f}%')
print(f'Test Set F-score score =  {100*f1_score(y_true, y_pred, average="macro"):.3}%')
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_27432/3830466417.py:3: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# Test Set Accuracy score =  68.765%
# Test Set Precision score =  47.700%
# Test Set Recall score =  46.576%
# Test Set F-score score =  46.6%

# %% [markdown]
# ##### Simple U_network

# %%
# baseline model
def create_3_layer():
    # create model
    model = Sequential()
    model.add(Dense(64, input_dim=train_features.shape[1], activation='relu')) # one hidden layer
    model.add(Dense(128, activation='relu')) # one hidden layer
    model.add(Dense(256, activation='relu')) # one hidden layer
    model.add(Dense(128, activation='relu')) # one hidden layer
    model.add(Dense(64, activation='relu')) # one hidden layer
    model.add(Dense(1, activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model = create_3_layer()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 64)                11584
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 94,145
# Trainable params: 94,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size=4, epochs=100, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 331/331 [==============================] - 1s 2ms/step - loss: 0.1704 - accuracy: 0.9494 - val_loss: 0.0335 - val_accuracy: 0.9879
# Epoch 2/100
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0352 - accuracy: 0.9947 - val_loss: 0.0333 - val_accuracy: 0.9909
# Epoch 3/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.5423e-04 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9970
# Epoch 4/100
# 331/331 [==============================] - 1s 2ms/step - loss: 5.9163e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9970
# Epoch 5/100
# 331/331 [==============================] - 1s 2ms/step - loss: 8.2241e-06 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9970
# Epoch 6/100
# 331/331 [==============================] - 1s 2ms/step - loss: 5.2797e-07 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 0.9970
# Epoch 7/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.3780e-07 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9970
# Epoch 8/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.4589e-07 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9970
# Epoch 9/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.2064e-07 - accuracy: 1.0000 - val_loss: 0.0157 - val_accuracy: 0.9970
# Epoch 10/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.0176e-07 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 0.9970
# Epoch 11/100
# 331/331 [==============================] - 1s 2ms/step - loss: 8.6149e-08 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 0.9970
# Epoch 12/100
# 331/331 [==============================] - 1s 2ms/step - loss: 7.5626e-08 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9970
# Epoch 13/100
# 331/331 [==============================] - 1s 2ms/step - loss: 6.1204e-08 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 0.9970
# Epoch 14/100
# 331/331 [==============================] - 1s 2ms/step - loss: 5.3955e-08 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9970
# Epoch 15/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.5180e-08 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9970
# Epoch 16/100
# 331/331 [==============================] - 1s 2ms/step - loss: 3.4670e-08 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9970
# Epoch 17/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.9419e-08 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 0.9970
# Epoch 18/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.8480e-08 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 0.9970
# Epoch 19/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.4765e-08 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 0.9970
# Epoch 20/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.3438e-08 - accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 0.9970
# Epoch 21/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.1055e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9970
# Epoch 22/100
# 331/331 [==============================] - 1s 2ms/step - loss: 8.2372e-09 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9970
# Epoch 23/100
# 331/331 [==============================] - 1s 2ms/step - loss: 6.6117e-09 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9970
# Epoch 24/100
# 331/331 [==============================] - 1s 2ms/step - loss: 6.5916e-09 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9970
# Epoch 25/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.4387e-09 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9970
# Epoch 26/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.9510e-09 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9970
# Epoch 27/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.1885e-09 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9970
# Epoch 28/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.3209e-09 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9970
# Epoch 29/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.9024e-09 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9970
# Epoch 30/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.8028e-09 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9970
# Epoch 31/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.1793e-09 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9970
# Epoch 32/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.3575e-09 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9970
# Epoch 33/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.0839e-09 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9970
# Epoch 34/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.0952e-09 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9970
# Epoch 35/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.7069e-09 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9970
# Epoch 36/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.4398e-09 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9970
# Epoch 37/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.2536e-09 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9970
# Epoch 38/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.1524e-09 - accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 0.9970
# Epoch 39/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.0912e-09 - accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 0.9970
# Epoch 40/100
# 331/331 [==============================] - 1s 2ms/step - loss: 8.5461e-10 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 0.9970
# Epoch 41/100
# 331/331 [==============================] - 1s 2ms/step - loss: 8.9670e-10 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9970
# Epoch 42/100
# 331/331 [==============================] - 1s 2ms/step - loss: 6.6687e-10 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9970
# Epoch 43/100
# 331/331 [==============================] - 1s 2ms/step - loss: 7.8904e-10 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9970
# Epoch 44/100
# 331/331 [==============================] - 1s 2ms/step - loss: 5.7179e-10 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9970
# Epoch 45/100
# 331/331 [==============================] - 1s 2ms/step - loss: 5.5268e-10 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9970
# Epoch 46/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.2047e-10 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9970
# Epoch 47/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.4234e-10 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9970
# Epoch 48/100
# 331/331 [==============================] - 1s 2ms/step - loss: 3.5688e-10 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 0.9970
# Epoch 49/100
# 331/331 [==============================] - 1s 2ms/step - loss: 3.3369e-10 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9970
# Epoch 50/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.8145e-10 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9970
# Epoch 51/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.6167e-10 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 0.9970
# Epoch 52/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.1914e-10 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9970
# Epoch 53/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.0533e-10 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9970
# Epoch 54/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.8337e-10 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9970
# Epoch 55/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.7136e-10 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9970
# Epoch 56/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.6083e-10 - accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 0.9970
# Epoch 57/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.3682e-10 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 0.9970
# Epoch 58/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.2877e-10 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 0.9970
# Epoch 59/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.2188e-10 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9970
# Epoch 60/100
# 331/331 [==============================] - 1s 2ms/step - loss: 9.5924e-11 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9970
# Epoch 61/100
# 331/331 [==============================] - 1s 2ms/step - loss: 9.5769e-11 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 0.9970
# Epoch 62/100
# 331/331 [==============================] - 1s 2ms/step - loss: 8.9055e-11 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9970
# Epoch 63/100
# 331/331 [==============================] - 1s 2ms/step - loss: 8.0310e-11 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9970
# Epoch 64/100
# 331/331 [==============================] - 1s 2ms/step - loss: 7.3609e-11 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9970
# Epoch 65/100
# 331/331 [==============================] - 1s 2ms/step - loss: 7.8482e-11 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 0.9970
# Epoch 66/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.0319e-10 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9970
# Epoch 67/100
# 331/331 [==============================] - 1s 2ms/step - loss: 6.4624e-11 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9970
# Epoch 68/100
# 331/331 [==============================] - 1s 2ms/step - loss: 7.1573e-11 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9970
# Epoch 69/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.7722e-11 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9970
# Epoch 70/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.8068e-11 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9970
# Epoch 71/100
# 331/331 [==============================] - 1s 2ms/step - loss: 6.0013e-11 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9970
# Epoch 72/100
# 331/331 [==============================] - 1s 2ms/step - loss: 6.7557e-11 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9970
# Epoch 73/100
# 331/331 [==============================] - 1s 2ms/step - loss: 7.8982e-11 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9970
# Epoch 74/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.2622e-11 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9970
# Epoch 75/100
# 331/331 [==============================] - 1s 2ms/step - loss: 3.6165e-11 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9970
# Epoch 76/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.5615e-11 - accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 0.9970
# Epoch 77/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.7869e-11 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9970
# Epoch 78/100
# 331/331 [==============================] - 1s 2ms/step - loss: 6.1003e-11 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9970
# Epoch 79/100
# 331/331 [==============================] - 1s 2ms/step - loss: 7.4674e-11 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 0.9970
# Epoch 80/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.5913e-10 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9970
# Epoch 81/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.8394e-11 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9970
# Epoch 82/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.7981e-11 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 0.9970
# Epoch 83/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.4970e-11 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9970
# Epoch 84/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.9267e-11 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9970
# Epoch 85/100
# 331/331 [==============================] - 1s 2ms/step - loss: 3.0967e-11 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9970
# Epoch 86/100
# 331/331 [==============================] - 1s 2ms/step - loss: 0.1353 - accuracy: 0.9872 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 87/100
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0385 - accuracy: 0.9932 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 88/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.0947e-04 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9970
# Epoch 89/100
# 331/331 [==============================] - 1s 2ms/step - loss: 5.7526e-05 - accuracy: 1.0000 - val_loss: 7.1975e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0055 - accuracy: 0.9992 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 91/100
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 7.5952e-05 - val_accuracy: 1.0000
# Epoch 92/100
# 331/331 [==============================] - 1s 2ms/step - loss: 9.1174e-08 - accuracy: 1.0000 - val_loss: 7.1584e-05 - val_accuracy: 1.0000
# Epoch 93/100
# 331/331 [==============================] - 1s 2ms/step - loss: 6.5088e-08 - accuracy: 1.0000 - val_loss: 6.0584e-05 - val_accuracy: 1.0000
# Epoch 94/100
# 331/331 [==============================] - 1s 2ms/step - loss: 4.5477e-08 - accuracy: 1.0000 - val_loss: 4.4014e-05 - val_accuracy: 1.0000
# Epoch 95/100
# 331/331 [==============================] - 1s 2ms/step - loss: 3.1054e-08 - accuracy: 1.0000 - val_loss: 3.1981e-05 - val_accuracy: 1.0000
# Epoch 96/100
# 331/331 [==============================] - 1s 2ms/step - loss: 2.1640e-08 - accuracy: 1.0000 - val_loss: 2.6259e-05 - val_accuracy: 1.0000
# Epoch 97/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.5349e-08 - accuracy: 1.0000 - val_loss: 2.0664e-05 - val_accuracy: 1.0000
# Epoch 98/100
# 331/331 [==============================] - 1s 2ms/step - loss: 1.1430e-08 - accuracy: 1.0000 - val_loss: 1.8465e-05 - val_accuracy: 1.0000
# Epoch 99/100
# 331/331 [==============================] - 1s 2ms/step - loss: 8.6323e-09 - accuracy: 1.0000 - val_loss: 1.6214e-05 - val_accuracy: 1.0000
# Epoch 100/100
# 331/331 [==============================] - 1s 2ms/step - loss: 6.7348e-09 - accuracy: 1.0000 - val_loss: 1.4049e-05 - val_accuracy: 1.0000

# %%
y_pred = model.predict_classes(test_features)
y_true = encoded_test_labels
print(f'Test Set Accuracy score =  {100*accuracy_score(y_true, y_pred):.3f}%') #same as model.score(X_test, y_test)
print(f'Test Set Precision score =  {100*precision_score(y_true, y_pred, average="macro"):.3f}%')
print(f'Test Set Recall score =  {100*recall_score(y_true, y_pred, average="macro"):.3f}%')
print(f'Test Set F-score score =  {100*f1_score(y_true, y_pred, average="macro"):.3}%')
# Out:
# Test Set Accuracy score =  67.635%
# Test Set Precision score =  47.708%
# Test Set Recall score =  46.433%
# Test Set F-score score =  46.4%

# %% [markdown]
# ##### Residual Network

# %% [markdown]
# ![An example Residual Block](src/residual.png)

# %%
def residual_block(x, filters, conv_num=3, activation="relu"):
    # Shortcut
    s = keras.layers.Conv1D(filters, 1, padding="same")(x)
    for i in range(conv_num - 1):
        x = keras.layers.Conv1D(filters, 3, padding="same")(x)
        x = keras.layers.Activation(activation)(x)
    x = keras.layers.Conv1D(filters, 3, padding="same")(x)
    x = keras.layers.Add()([x, s])
    x = keras.layers.Activation(activation)(x)
    return keras.layers.MaxPool1D(pool_size=2, strides=2)(x)


def build_model(input_shape, num_classes):
    inputs = keras.layers.Input(shape=input_shape, name="input")

    x = residual_block(inputs, 16, 2)
    x = residual_block(x, 32, 2)
    x = residual_block(x, 64, 3)
    x = residual_block(x, 128, 3)
    x = residual_block(x, 128, 3)

    x = keras.layers.AveragePooling1D(pool_size=3, strides=3)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(256, activation="relu")(x)
    x = keras.layers.Dense(128, activation="relu")(x)

    outputs = keras.layers.Dense(num_classes, activation="sigmoid", name="output")(x)

    return keras.models.Model(inputs=inputs, outputs=outputs)

# %%
model = build_model((180, 1), 1)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 180, 1)]     0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 180, 16)      64          input[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 180, 16)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 180, 16)      784         activation[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 180, 16)      32          input[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 180, 16)      0           conv1d_2[0][0]
#                                                                  conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 180, 16)      0           add[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 90, 16)       0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 90, 32)       1568        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 90, 32)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 90, 32)       3104        activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 90, 32)       544         max_pooling1d[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 90, 32)       0           conv1d_5[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 90, 32)       0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 45, 32)       0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 45, 64)       6208        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 45, 64)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 45, 64)       12352       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 45, 64)       0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 45, 64)       12352       activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 45, 64)       2112        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 45, 64)       0           conv1d_9[0][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 45, 64)       0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 22, 64)       0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 22, 128)      24704       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 22, 128)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 22, 128)      49280       activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 22, 128)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 22, 128)      49280       activation_8[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 22, 128)      8320        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 22, 128)      0           conv1d_13[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 22, 128)      0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 11, 128)      0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 11, 128)      49280       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 11, 128)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 11, 128)      49280       activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 11, 128)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 11, 128)      49280       activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 11, 128)      16512       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 11, 128)      0           conv1d_17[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 11, 128)      0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 5, 128)       0           activation_12[0][0]
# __________________________________________________________________________________________________
# average_pooling1d (AveragePooli (None, 1, 128)       0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 128)          0           average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 256)          33024       flatten[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 128)          32896       dense_8[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            129         dense_9[0][0]
# ==================================================================================================
# Total params: 401,105
# Trainable params: 401,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer="Adam", loss="binary_crossentropy", metrics=["accuracy"]
)

# %%
model_save_filename = "model.h5"

earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
mdlcheckpoint_cb = keras.callbacks.ModelCheckpoint(
    model_save_filename, monitor="val_accuracy", save_best_only=True
)

# %%
model.fit(X_train, y_train, batch_size=4, epochs=100, verbose=1, validation_data=(X_test, y_test),
         callbacks=[earlystopping_cb, mdlcheckpoint_cb],)
# Out:
# Epoch 1/100
# 2021-10-25 01:55:03.781245: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 331/331 [==============================] - 2s 6ms/step - loss: 0.3444 - accuracy: 0.8678 - val_loss: 0.0915 - val_accuracy: 0.9789
# Epoch 2/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.1120 - accuracy: 0.9630 - val_loss: 0.1033 - val_accuracy: 0.9668
# Epoch 3/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0957 - accuracy: 0.9736 - val_loss: 0.1550 - val_accuracy: 0.9698
# Epoch 4/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0758 - accuracy: 0.9789 - val_loss: 0.0785 - val_accuracy: 0.9819
# Epoch 5/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.1305 - accuracy: 0.9668 - val_loss: 0.0743 - val_accuracy: 0.9879
# Epoch 6/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0767 - accuracy: 0.9751 - val_loss: 0.0975 - val_accuracy: 0.9789
# Epoch 7/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0694 - accuracy: 0.9811 - val_loss: 0.0349 - val_accuracy: 0.9849
# Epoch 8/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0615 - accuracy: 0.9789 - val_loss: 0.0955 - val_accuracy: 0.9758
# Epoch 9/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0381 - accuracy: 0.9887 - val_loss: 0.0714 - val_accuracy: 0.9637
# Epoch 10/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0756 - accuracy: 0.9751 - val_loss: 0.0979 - val_accuracy: 0.9758
# Epoch 11/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0460 - accuracy: 0.9864 - val_loss: 0.0552 - val_accuracy: 0.9909
# Epoch 12/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.0344 - val_accuracy: 0.9879
# Epoch 13/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0238 - accuracy: 0.9887 - val_loss: 0.0689 - val_accuracy: 0.9849
# Epoch 14/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0369 - accuracy: 0.9932 - val_loss: 0.1671 - val_accuracy: 0.9849
# Epoch 15/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0900 - accuracy: 0.9856 - val_loss: 0.0791 - val_accuracy: 0.9849
# Epoch 16/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0343 - accuracy: 0.9909 - val_loss: 0.0432 - val_accuracy: 0.9879
# Epoch 17/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0224 - accuracy: 0.9955 - val_loss: 0.0432 - val_accuracy: 0.9879
# Epoch 18/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0450 - accuracy: 0.9894 - val_loss: 0.3430 - val_accuracy: 0.8218
# Epoch 19/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0390 - accuracy: 0.9864 - val_loss: 0.0600 - val_accuracy: 0.9879
# Epoch 20/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0411 - accuracy: 0.9879 - val_loss: 0.0976 - val_accuracy: 0.9879
# Epoch 21/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0461 - accuracy: 0.9834 - val_loss: 0.0875 - val_accuracy: 0.9819
# Epoch 22/100
# 331/331 [==============================] - 2s 5ms/step - loss: 0.0403 - accuracy: 0.9856 - val_loss: 0.1227 - val_accuracy: 0.9789

# %%
y_pred = model.predict(test_features)
y_pred = np.where(y_pred >= 0.5, 1, 0).flatten()
print(f'Test Set Accuracy score =  {100*accuracy_score(y_true, y_pred):.3f}%') #same as model.score(X_test, y_test)
print(f'Test Set Precision score =  {100*precision_score(y_true, y_pred, average="macro"):.3f}%')
print(f'Test Set Recall score =  {100*recall_score(y_true, y_pred, average="macro"):.3f}%')
print(f'Test Set F-score score =  {100*f1_score(y_true, y_pred, average="macro"):.3}%')
# Out:
# Test Set Accuracy score =  83.777%
# Test Set Precision score =  65.196%
# Test Set Recall score =  65.428%
# Test Set F-score score =  65.3%
